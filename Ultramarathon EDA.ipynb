# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/adars/Desktop/Practice_Python_Data/UM_RACES.csv')
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_10512\78743283.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/adars/Desktop/Practice_Python_Data/UM_RACES.csv')

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
# Data Cleaning
#50mi


df[df['Event distance/length'] == "50mi"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
df[df['Event distance/length'].isin(["50mi","50k"])]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# Show USA races from 2020, 50mi, or 50km
# Using athlete country won' t work
df[(df['Event distance/length'].isin(["50mi","50k"])) & (df["Year of event"] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2757700           2020      08.10.2020
# 2757701           2020      08.10.2020
# 2757702           2020      08.10.2020
# 2757703           2020      08.10.2020
# 2757704           2020      08.10.2020
#
#                                                Event name  \
# 2538571           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538572           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538573           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538574           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538575           Taipei 48hr Ultra Marathon - 50mi (TPE)
# ...                                                   ...
# 2757700  Täby Extreme Challenge 50 miles - Thursday (SWE)
# ...

# %%
usa = "(USA)"
df["USA_races"] = df['Event name'].str.find(usa)

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
df.drop('USA_races', axis = 1)
# Out:
#          Year of event Event dates                                Event name  \
# 0                 2018  06.01.2018                       Selva Costera (CHI)
# 1                 2018  06.01.2018                       Selva Costera (CHI)
# 2                 2018  06.01.2018                       Selva Costera (CHI)
# 3                 2018  06.01.2018                       Selva Costera (CHI)
# 4                 2018  06.01.2018                       Selva Costera (CHI)
# ...                ...         ...                                       ...
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
# ...

# %%
#Split at first (, then split at second ) then take just the USA

df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 0          CHI
# 1          CHI
# 2          CHI
# 3          CHI
# 4          CHI
#           ...
# 7461190    FRA
# 7461191    FRA
# 7461192    HUN
# 7461193    HUN
# 7461194    HUN
# Name: Event name, Length: 7461195, dtype: object

# %%
df2 = df[(df['Event distance/length'].isin(["50mi","50km"])) & (df["Year of event"] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
#Clean up athlete age so that the numbers are usable as int

df2["Athlete year of birth"].head()
# Out:
# 2539945    1991.0
# 2539946    1981.0
# 2539947    1999.0
# 2539948    1983.0
# 2539949    1977.0
# Name: Athlete year of birth, dtype: float64

# %%
df2["Athlete age"] = 2020 - df2["Athlete year of birth"]
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_10512\1209317780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete age"] = 2020 - df2["Athlete year of birth"]

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
#remove the .0 from athlete age

import math

# %%
df2['athlete age'] = df2['athlete age'].astype(str).apply(lambda x: x.replace('.0',''))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'athlete age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2.head()
# Out:
#          Year Event dates                       Event name Race_length  \
# 2542134  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
# 2542135  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
# 2542136  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
# 2542137  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
# 2542138  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
#
#          Event number of finishers Athlete_performance     Athlete club  \
# 2542134                         10           8:51:11 h     *Phoenix, AZ
# 2542135                         10          11:37:15 h     *Phoenix, AZ
# 2542136                         10          11:59:00 h          *London
# 2542137                         10          12:04:40 h         *Fpo, AZ
# 2542138                         10          12:26:20 h  *Saint Paul, MN
#
#         Athlete country  Athlete year of birth Athlete_gender  \
# ...

# %%
df2 = df2.rename(columns = {"Year of event" :  "Year", "Event distance/length" : "Race_length","Athlete performance" : "Athlete_performance", "Athlete gender" : "Athlete_gender","Athlete average speed" : "Athlete_average_speed","athlete age" : "athlete_age","Athlete id" : "Athlete_id"})

# %%
df2.head()
# Out:
#          Year Event dates                                     Event name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         Race_length  Event number of finishers Athlete_performance  \
# 2539945        50km                         20           3:17:55 h
# 2539946        50km                         20           4:02:32 h
# 2539947        50km                         20           4:07:57 h
# 2539948        50km                         20           4:22:02 h
# 2539949        50km                         20           4:27:34 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# ...

# %%
# find specific values

everglades_races = df2[df2["Event name"] == "Elephant Mountain 50 Mile (USA)"]
everglades_races.head()
# Out:
#          Year Event dates                       Event name Race_length  \
# 2542134  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
# 2542135  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
# 2542136  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
# 2542137  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
# 2542138  2020  01.02.2020  Elephant Mountain 50 Mile (USA)        50mi
#
#          Event number of finishers Athlete_performance     Athlete club  \
# 2542134                         10           8:51:11 h     *Phoenix, AZ
# 2542135                         10          11:37:15 h     *Phoenix, AZ
# 2542136                         10          11:59:00 h          *London
# 2542137                         10          12:04:40 h         *Fpo, AZ
# 2542138                         10          12:26:20 h  *Saint Paul, MN
#
#         Athlete country  Athlete year of birth Athlete_gender  \
# ...

# %%
#find id 222509

df2[df2["Athlete ID"] == 222509]
# Out:
#          Year Event dates                          Event name Race_length  \
# 2591482  2020  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
#
#          Event number of finishers Athlete_performance  Athlete club  \
# 2591482                         40           9:19:10 h  *Dunedin, FL
#
#         Athlete country  Athlete year of birth Athlete_gender  \
# 2591482             USA                 1997.0              M
#
#         Athlete age category Athlete_average_speed  Athlete ID  Athlete age
# 2591482                 MU23                 8.634      222509         23.0

# %%
sns.histplot(df2["Race_length"])
# Out:
# <Axes: xlabel='Race_length', ylabel='Count'>

# %%
df2[df2["Race_length"] == "50km"]
# Out:
#          Year Event dates                                     Event name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# ...       ...         ...                                            ...
# 2760957  2020  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
# 2760958  2020  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
# 2760959  2020  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
# 2760960  2020  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
# 2760961  2020  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
#
#         Race_length  Event number of finishers Athlete_performance  \
# ...
